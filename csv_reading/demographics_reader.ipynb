# %%
import csv

demographics_dict = {}
with open('../unrestricted_baes4_7_26_2019_13_23_12.csv') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    line_count = 0
    for row in csv_reader:
        print(row['Subject'], row['Gender'], row['Age'])
        demographics_dict[row['Subject']] = (row['Gender'], row['Age'])
# Out:
# 100307 F 26-30
# 102816 F 26-30
# 104012 F 26-30
# 105923 F 31-35
# 106521 F 26-30
# 108323 F 26-30
# 109123 M 31-35
# 111514 M 31-35
# 112920 M 31-35
# 113922 M 31-35
# 116524 M 26-30
# 116726 M 26-30
# 125525 F 31-35
# 133019 F 26-30
# 140117 F 26-30
# 146129 M 22-25
# 149741 M 26-30
# 151526 M 26-30
# 153732 F 26-30
# 154532 M 26-30
# 156334 F 26-30
# 158136 M 31-35
# 162026 F 31-35
# 162935 M 22-25
# 164636 M 22-25
# 166438 M 31-35
# 169040 M 22-25
# 172029 M 26-30
# 174841 M 22-25
# 175237 F 31-35
# 175540 M 31-35
# 177746 F 26-30
# 179245 F 31-35
# 181232 F 26-30
# 182840 M 31-35
# 185442 M 22-25
# 187547 F 31-35
# 189349 F 26-30
# 191033 F 26-30
# 191437 F 31-35
# 191841 F 26-30
# 192641 F 31-35
# 195041 F 31-35
# 198653 M 22-25
# 200109 F 31-35
# 204521 F 31-35
# 205119 M 31-35
# 212318 F 31-35
# 212823 M 22-25
# 214524 M 22-25
# 221319 F 26-30
# 223929 M 31-35
# 233326 M 31-35
# 248339 M 26-30
# 250427 F 31-35
# 255639 F 26-30
# 257845 M 26-30
# 283543 M 22-25
# ...

# %%
demographics_dict
# Out:
# {'100307': ('F', '26-30'),
#  '102816': ('F', '26-30'),
#  '104012': ('F', '26-30'),
#  '105923': ('F', '31-35'),
#  '106521': ('F', '26-30'),
#  '108323': ('F', '26-30'),
#  '109123': ('M', '31-35'),
#  '111514': ('M', '31-35'),
#  '112920': ('M', '31-35'),
#  '113922': ('M', '31-35'),
#  '116524': ('M', '26-30'),
#  '116726': ('M', '26-30'),
#  '125525': ('F', '31-35'),
#  '133019': ('F', '26-30'),
#  '140117': ('F', '26-30'),
#  '146129': ('M', '22-25'),
#  '149741': ('M', '26-30'),
#  '151526': ('M', '26-30'),
#  '153732': ('F', '26-30'),
#  '154532': ('M', '26-30'),
#  '156334': ('F', '26-30'),
#  '158136': ('M', '31-35'),
#  '162026': ('F', '31-35'),
#  '162935': ('M', '22-25'),
#  '164636': ('M', '22-25'),
#  '166438': ('M', '31-35'),
#  '169040': ('M', '22-25'),
#  '172029': ('M', '26-30'),
#  '174841': ('M', '22-25'),
#  '175237': ('F', '31-35'),
#  '175540': ('M', '31-35'),
#  '177746': ('F', '26-30'),
#  '179245': ('F', '31-35'),
#  '181232': ('F', '26-30'),
# ...
